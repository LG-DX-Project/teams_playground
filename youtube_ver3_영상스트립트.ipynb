# %% [markdown]
# ### 유튜브 영상 댓글 크롤링 ver3
# - 영상 자막 스크립트 크롤링 코드

# %%
####### 구버전이라 이거 실행 안됨

# from youtube_transcript_api import YouTubeTranscriptApi

# video_id = 'dFRXcYJVfMM'
# transcription = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko', 'en'])
# for content in transcription:
#     print(content)

# ## 아래 쉘로 실행하면 돌아감

# %%
######### 신버전 ##########
from youtube_transcript_api import YouTubeTranscriptApi

video_id = "lxZsn3cwdAU"

api = YouTubeTranscriptApi()
transcription = api.fetch(video_id, languages=['ko', 'en'])

for seg in transcription:
    print(seg.text)
# Out:
# 진공 와우로 듣게 되면 소리가 어떻게
# 들리는데요 정확히 그 자료화 했는데
# 들려드릴게요
# 원음이요 이제 일반 소리
# [음악]
# 근데 이거 다음 인공와우예요
# 이렇게 들립니다
